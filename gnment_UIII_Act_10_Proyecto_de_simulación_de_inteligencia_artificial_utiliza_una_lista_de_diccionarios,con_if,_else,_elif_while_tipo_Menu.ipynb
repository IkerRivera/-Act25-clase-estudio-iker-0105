# %% [markdown]
# <a href="https://colab.research.google.com/github/IkerRivera/-Act25-clase-estudio-iker-0105/blob/main/gnment_UIII_Act_10_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_utiliza_una_lista_de_diccionarios%2Ccon_if%2C_else%2C_elif_while_tipo_Menu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================
# SISTEMA IA MILITAR
# LISTA DE DICCIONARIOS
# Nivel: Principiante
# =========================================

# Lista vacia
militar = []
los_militares = []

while True:

    print("\n========================================")
    print("        SISTEMA IA MILITAR")
    print("========================================")

    print("1. Registrar militar")
    print("2. Ver lista de militares")
    print("3. Analizar combate")
    print("4. Revisar energia")
    print("5. Salir")

    opcion = int(input("\nSelecciona una opcion: "))

    # =====================================
    # OPCION 1 - REGISTRAR MILITAR
    # =====================================

    if opcion == 1:

        print("\n========== REGISTRO MILITAR ==========")

        # Diccionario vacio
        militar = {}

        nombre = input("Nombre del militar: ")
        rango = input("Rango militar: ")
        arma = input("Arma principal: ")
        energia = input("Nivel de energia: ")

        militar["Nombre"] = nombre
        militar["Rango"] = rango
        militar["Arma"] = arma
        militar["Energia"] = energia

        militares.append(militar)

        print("\nIA: Militar registrado correctamente")

    # =====================================
    # OPCION 2 - VER MILITARES
    # =====================================

    elif opcion == 2:

        print("\n============== LISTA DE MILITARES ==============")

        if militares == []:

            print("\nIA: No hay militares registrados")

        else:

            print("----------------------------------------------------------------")
            print("NOMBRE         | RANGO          | ARMA           | ENERGIA")
            print("----------------------------------------------------------------")

            for militar in militares:

                print(
                    f"{militar['Nombre']:<15} | "
                    f"{militar['Rango']:<15} | "
                    f"{militar['Arma']:<15} | "
                    f"{militar['Energia']}"
                )

            print("----------------------------------------------------------------")

    # =====================================
    # OPCION 3 - ANALISIS DE COMBATE
    # =====================================

    elif opcion == 3:

        print("\n========== ANALISIS DE COMBATE ==========")

        enemigos = int(input("Cantidad de enemigos: "))
        municion = int(input("Cantidad de municion: "))

        if enemigos > 50 and municion > 80:

            print("\nIA: ATAQUE TOTAL AUTORIZADO")

        elif enemigos > 20 and municion > 40:

            print("\nIA: COMBATE DIRECTO")

        elif enemigos > 10 and municion < 30:

            print("\nIA: RETIRADA ESTRATEGICA")

        else:

            print("\nIA: ZONA SEGURA")

    # =====================================
    # OPCION 4 - ESTADO MILITAR
    # =====================================

    elif opcion == 4:

        print("\n========== ESTADO MILITAR ==========")

        energia = int(input("Nivel de energia del soldado: "))

        if energia >= 80:

            print("\nIA: SOLDADO EN PERFECTO ESTADO")

        elif energia >= 50:

            print("\nIA: SOLDADO ESTABLE")

        elif energia >= 20:

            print("\nIA: SOLDADO CANSADO")

        else:

            print("\nIA: DESCANSO OBLIGATORIO")

    # =====================================
    # OPCION 5 - SALIR
    # =====================================

    elif opcion == 5:

        print("\nSistema finalizado")
        break

    # =====================================
    # OPCION INVALIDA
    # =====================================

    else:

        print("\nOpcion no valida")
# Out:
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 1
#
# ========== REGISTRO MILITAR ==========
# Nombre del militar: page
# Rango militar: alpa
# Arma principal: fusil
# Nivel de energia: 100
#
# IA: Militar registrado correctamente
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 2
#
# ============== LISTA DE MILITARES ==============
# ----------------------------------------------------------------
# NOMBRE         | RANGO          | ARMA           | ENERGIA
# ----------------------------------------------------------------
# page            | alpa            | fusil           | 100
# ----------------------------------------------------------------
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 1
#
# ========== REGISTRO MILITAR ==========
# Nombre del militar: iker
# Rango militar: lider
# Arma principal: sniper
# Nivel de energia: 26
#
# IA: Militar registrado correctamente
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 2
#
# ============== LISTA DE MILITARES ==============
# ----------------------------------------------------------------
# NOMBRE         | RANGO          | ARMA           | ENERGIA
# ----------------------------------------------------------------
# page            | alpa            | fusil           | 100
# iker            | lider           | sniper          | 26
# ----------------------------------------------------------------
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 1
#
# ========== REGISTRO MILITAR ==========
# Nombre del militar: nahum
# Rango militar: eco
# Arma principal: bolas
# Nivel de energia: 67
#
# IA: Militar registrado correctamente
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 2
#
# ============== LISTA DE MILITARES ==============
# ----------------------------------------------------------------
# NOMBRE         | RANGO          | ARMA           | ENERGIA
# ----------------------------------------------------------------
# page            | alpa            | fusil           | 100
# iker            | lider           | sniper          | 26
# nahum           | eco             | bolas           | 67
# ----------------------------------------------------------------
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 1
#
# ========== REGISTRO MILITAR ==========
# Nombre del militar: hugo
# Rango militar: beta
# Arma principal: espada
# Nivel de energia: 45
#
# IA: Militar registrado correctamente
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 2
#
# ============== LISTA DE MILITARES ==============
# ----------------------------------------------------------------
# NOMBRE         | RANGO          | ARMA           | ENERGIA
# ----------------------------------------------------------------
# page            | alpa            | fusil           | 100
# iker            | lider           | sniper          | 26
# nahum           | eco             | bolas           | 67
# hugo            | beta            | espada          | 45
# ----------------------------------------------------------------
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 3
#
# ========== ANALISIS DE COMBATE ==========
# Cantidad de enemigos: 27
# Cantidad de municion: 21
#
# IA: RETIRADA ESTRATEGICA
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 4
#
# ========== ESTADO MILITAR ==========
# Nivel de energia del soldado: 67
#
# IA: SOLDADO ESTABLE
#
# ========================================
#         SISTEMA IA MILITAR
# ========================================
# 1. Registrar militar
# 2. Ver lista de militares
# 3. Analizar combate
# 4. Revisar energia
# 5. Salir
#
# Selecciona una opcion: 5
#
# Sistema finalizado

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/IkerRivera/-Act25-clase-estudio-iker-0105/refs/heads/main/militar%207832637834267843287624387.png)
