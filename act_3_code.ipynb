# %% [markdown]
# <a href="https://colab.research.google.com/github/IkerRivera/-Act25-clase-estudio-iker-0105/blob/main/act_3_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sistema básico de inicio de sesión

# Variables para guardar datos
usuario_guardado = ""
contrasena_guardada = ""

# Variable para controlar el programa
opcion = 0

# Menú principal
while opcion != 3:

    print("\n--- MENÚ PRINCIPAL ---")
    print("1. Registrarse")
    print("2. Iniciar sesión")
    print("3. Salir")

    opcion = int(input("Selecciona una opción: "))

    # Opción 1: Registrarse
    if opcion == 1:
        usuario_guardado = input("Crea un usuario: ")
        contrasena_guardada = input("Crea una contraseña: ")
        print("Registro exitoso")

    # Opción 2: Iniciar sesión
    elif opcion == 2:
        usuario = input("Ingresa tu usuario: ")
        contrasena = input("Ingresa tu contraseña: ")

        if usuario == usuario_guardado and contrasena == contrasena_guardada:
            print("Inicio de sesión exitoso")
        else:
            print("Usuario o contraseña incorrectos")

    # Opción 3: Salir
    elif opcion == 3:
        print("Saliendo del sistema...")

    # Opción inválida
    else:
        print("Opción no válida")
# Out:
# --- MENÚ PRINCIPAL ---
# 1. Registrarse
# 2. Iniciar sesión
# 3. Salir
# Selecciona una opción: 1
# Crea un usuario: iker
# Crea una contraseña: paviño0105
# Registro exitoso
#
# --- MENÚ PRINCIPAL ---
# 1. Registrarse
# 2. Iniciar sesión
# 3. Salir
# Selecciona una opción: 2
# Ingresa tu usuario: iker
# Ingresa tu contraseña: paviño0105
# Inicio de sesión exitoso
#
# --- MENÚ PRINCIPAL ---
# 1. Registrarse
# 2. Iniciar sesión
# 3. Salir
# Selecciona una opción: 3
# Saliendo del sistema...
